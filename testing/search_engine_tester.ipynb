# %% [markdown]
# # TripPal Search Engine
# this search engine provides integration between different data APIs; like `Dojo Hotel` and `OpenTripMap`

# %%
import pandas as pd
import numpy as np
import requests 
import json
import math
import sys
from pathlib import Path

module_path = str(Path.cwd().parents[0] / "SearchEngine")

if module_path not in sys.path:
    sys.path.append(module_path)

from Search_engine import Search_Engine 
from utils import data_parser as dp
from utils import constants as c

# %%
def list_to_str(s): 
    str1 = "" 
    for ele in s: 
        str1 += ele 
        str1 += ','
    return str1

# %% [markdown]
# ### Section One - Hotels search engine testing

# %%
search_engine = Search_Engine()

# %%
res0 = search_engine.get('HOTELS', 'BESTCHOISE', {'location' : 'new yourk'})
# Out:
# Hotels search engine in use!

# %%
res0['0']
# Out:
# {'id': 114697,
#  'name': 'Gramercy Park Hotel',
#  'starRating': 5.0,
#  'guestrating': '8.4',
#  'address': 'New York',
#  'street': 'New York',
#  'price': '',
#  'features': '',
#  'imgURL': 'https://thumbnails.trvl-media.com/UyEE7VrYCnU6qmrll1Q7sl0jKT8=/250x140/smart/filters:quality(60)/images.trvl-media.com/hotels/1000000/30000/20600/20525/2cf830aa_z.jpg',
#  'coordinate': {'lat': 40.738502, 'lon': -73.985565},
#  'deals': {}}

# %%
booking_dict = {
    'location' : 'new yourk',
    'page_number' : 1,
    'check_in_date' : "2021-03-16",
    'check_out_date' : "2021-03-20",
    'adults' : 1,
    'sort_order' : 'GUEST_RATING'
}

# %%
res1 = search_engine.get('HOTELS', 'BOOK', booking_dict)
# Out:
# Hotels search engine in use!

# %%
res1['HOTELS']['0']
# Out:
# {'id': 538659,
#  'name': 'Wythe Hotel',
#  'starRating': 3.5,
#  'guestrating': '10.0',
#  'address': 'Brooklyn',
#  'street': 'Brooklyn',
#  'price': {'old_price': 240.0, 'new_price': '$240'},
#  'features': {'paymentPreference': False, 'noCCRequired': False},
#  'imgURL': 'https://thumbnails.trvl-media.com/4z7BJsPsNLJsvaD6TZgS6H48VEc=/250x140/smart/filters:quality(60)/images.trvl-media.com/hotels/5000000/4960000/4952200/4952112/28963bb4_z.jpg',
#  'coordinate': {'lat': 40.722088, 'lon': -73.957697},
#  'deals': {}}

# %%
res1['FILTERS']['starRating']
# Out:
# {'applied': False,
#  'items': [{'value': 5},
#   {'value': 4},
#   {'value': 3},
#   {'value': 2},
#   {'value': 1}]}

# %%
res2 = search_engine.get('HOTELS', 'DETAILS', {'id' : 538659})
# Out:
# Hotels search engine in use!

# %%
res2
# Out:
# {'HOTEL_FEATURE': ['72 smoke-free guestrooms',
#   'Daily housekeeping',
#   'Restaurant and bar/lounge',
#   'Breakfast available',
#   '6 meeting rooms',
#   '24-hour front desk',
#   'Air conditioning',
#   'Garden',
#   'Laundry service',
#   'Conference space',
#   'Multilingual staff',
#   'Concierge services',
#   'Free WiFi '],
#  'LOCATION_SECTION': ['In Williamsburg',
#   'United Nations Headquarters - 3 mi / 4.8 km',
#   'Empire State Building - 3 mi / 4.9 km',
#   'Roosevelt Island - 2.6 mi / 4.2 km',
#   'Brooklyn Bridge Park - 3.7 mi / 6 km',
#   'Washington Square Park - 4 mi / 6.5 km',
#   'New York University - 4.1 mi / 6.6 km',
#   'Union Square Park - 4.3 mi / 6.9 km',
#   'Chrysler Building - 4.3 mi / 6.9 km',
#   'Barclays Center Brooklyn - 4.4 mi / 7 km',
#   'Wall Street - 4.4 mi / 7 km'],
#  'TAGLINE': ['<b>3.5-star hotel in Williamsburg with restaurant and bar/lounge </b>'],
#  'HOTEL_FREEBIES': ['Free WiFi'],
#  'NAME': 'Wythe Hotel',
#  'STAR_RATE': 3.5,
#  'PRICE': 245.0,
#  'longitude': -73.957697,
#  'latitude': 40.722088,
#  'ROOMS': ['BROOKLYN KING ROOM',
#   'BROOKLYN QUEEN ROOM',
#   'BUNK BED',
#   'MANHATTAN VIEW KING ROOM',
#   'STUDIO QUEEN ROOM'],
#  'ROOM_FEATURES': ['Air conditioning',
#   'Minibar',
#   'Bathrobes',
#   'Iron/ironing board',
#   'Blackout drapes/curtains',
#   'In-room massage available',
#   'Individually decorated',
#   'Rainfall showerhead',
#   'Shower only',
#   'Free toiletries',
#   'Hair dryer',
#   '40-inch Smart TV',
#   'Premium TV channels',
#   'Smart speaker',
#   'Free newspaper',
#   'Free WiFi',
#   'Free long-distance calls',
#   'Daily housekeeping',
#   'In-room safe'],
#  'HOTEL_FEATURES': [{'heading': 'Food and drink',
#    'listItems': ['Continental breakfast daily (surcharge)',
#     'Restaurant',
#     'Bar/lounge']},
#   {'heading': 'Working away',
#    'listItems': ['Number of meeting rooms -  6',
#     'Conference space',
#     'Conference space size (feet) -  3000',
#     'Conference space size (meters) -  279']},
#   {'heading': 'Services',
#    'listItems': ['24-hour front desk',
#     'Concierge services',
#     'Dry cleaning/laundry service',
#     'Free newspapers in lobby',
#     'Luggage storage',
#     'Wedding services',
#     'Multilingual staff',
#     'Porter/bellhop']},
#   {'heading': 'Facilities', 'listItems': ['Elevator', 'Garden']},
#   {'heading': 'Accessibility',
#    'listItems': ['Braille or raised signage',
#     'Accessible bathroom',
#     'In-room accessibility',
#     'Roll-in shower',
#     'Wheelchair-accessible path of travel',
#     'Wheelchair-accessible public restroom',
#     'Wheelchair-accessible path to lift',
#     'Wheelchair-accessible registration desk',
#     'Wheelchair-accessible meeting spaces/business center',
#     'Wheelchair-accessible on-site restaurant',
#     'Visual alarms in hallways',
#     'Handrails in hallways',
#     'Handrails in stairways',
#     'Braille signage',
#     'Hand-held showerhead',
#     'Wheelchair-accessible bathroom vanity',
#     'Portable shower seat',
#     'Raised toilet seat',
#     'Height-adjustable showerhead',
#     'Grab bar - near toilet',
#     'Grab bar - in shower',
#     'Roll-in shower',
#     'Visual fire alarm']},
#   {'heading': 'Languages Spoken', 'listItems': ['English']}],
#  'HYGIENE': 'COVID-19: Hygiene and cleanliness',
#  'Dining': "<strong>Le Crocodile</strong> - Onsite brasserie. <br/>\n<p></p><strong>Lemon's</strong> - Onsite rooftop bar. Open daily. ",
#  'POLICIES': '<p>This property advises that enhanced cleaning and guest safety measures are currently in place.</p><p>Disinfectant is used to clean the property, and commonly-touched surfaces are cleaned with disinfectant between stays.</p><p>Staff at the property wear personal protective equipment and masks are required in public areas.</p><p>Contactless check-in is available.</p>',
#  'PETS': ['Pets allowed (dogs only)*', 'Food and water bowls available'],
#  'INTERNET': ['Free WiFi in public areas', 'Free WiFi in rooms'],
#  'MAP_URL': 'https://maps-api-ssl.google.com/maps/api/staticmap?center=40.722088,-73.957697&format=jpg&sensor=false&key=AIzaSyDaDqDNrxWrxcURixO2l6TbtV68X0Klf4U&zoom=16&size=834x443&scale&signature&signature=6eyqYjrk9-ogCEmqPJkVhk-WLOQ=',
#  'CHECKIN_REQUIRED': ['Credit card, debit card, or cash deposit required for incidental charges',
#   'Government-issued photo ID may be required',
#   'Minimum check-in age is 18']}

# %%
features = list_to_str(res2['HOTEL_FEATURE']) + list_to_str(res2['HOTEL_FREEBIES']) + list_to_str(res2['ROOMS']) +  list_to_str(res2['ROOM_FEATURES'])

# %%
features
# Out:
# '72 smoke-free guestrooms,Daily housekeeping,Restaurant and bar/lounge,Breakfast available,6 meeting rooms,24-hour front desk,Air conditioning,Garden,Laundry service,Conference space,Multilingual staff,Concierge services,Free WiFi ,Free WiFi,BROOKLYN KING ROOM,BROOKLYN QUEEN ROOM,BUNK BED,MANHATTAN VIEW KING ROOM,STUDIO QUEEN ROOM,Air conditioning,Minibar,Bathrobes,Iron/ironing board,Blackout drapes/curtains,In-room massage available,Individually decorated,Rainfall showerhead,Shower only,Free toiletries,Hair dryer,40-inch Smart TV,Premium TV channels,Smart speaker,Free newspaper,Free WiFi,Free long-distance calls,Daily housekeeping,In-room safe,'

# %%
with open('details_sample.json', 'w') as f:
    json.dump(res2, f)

# %%
res3 = search_engine.get('HOTELS', 'IMAGES', {'id' : 538659})
# Out:
# Hotels search engine in use!

# %%
json.loads(res3)[0]
# Out:
# 'https://exp.cdn-hotels.com/hotels/5000000/4960000/4952200/4952112/28963bb4.jpg'

# %%
res4 = search_engine.get('HOTELS', 'REVIEWS', {'id' : 538659, 'page_number' : 1})
# Out:
# Hotels search engine in use!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a8d0f840a604> in <module>
# ----> 1 res4 = search_engine.get('HOTELS', 'REVIEWS', {'id' : 538659, 'page_number' : 1})
#
# ~/Desktop/Workstation/Trips-planning-system/Search_engine.py in get(self, engine_type, end_point, query_params)
#     216         if engine_type == 'HOTELS':
#     217             print('Hotels search engine in use!')
# --> 218             return hotel_search_engine_endpoints_es(end_point, query_params)
#     219
#     220         elif engine_type == 'PLACES':
#
# ~/Desktop/Workstation/Trips-planning-system/Search_engine.py in hotel_search_engine_endpoints_es(end_point, query_params)
#     140                 elif end_point == 'REVIEWS':
#     141                     if 'id' in query_params and 'page_number' in query_params:
# --> 142                         return self.hotels.get_hotel_reviews(query_params['id'], query_params['page_number'])
#     143                     else:
#     144                         raise ValueError('There is something missed in the query_params!')
#
# ~/Desktop/Workstation/Trips-planning-system/utils/hotels_engine.py in get_hotel_reviews(self, hotel_id, pn)
#     170         response = requests.request("GET", url, headers=self.headers, params = {"id":hotel_id ,"page": pn,"loc":"en_US"})
#     171
# --> 172         json_data = json.loads(response.text)['reviewData']['guestReviewGroups']['guestReviews'][0]['reviews']
#     173
#     174         res = []
#
# KeyError: 'reviewData'

# %%
json.loads(res4)[0]
# Out:
# {'user': 'Brittany',
#  'rating': 10.0,
#  'title': 'Amazing views!',
#  'review': 'Such a pleasant stay! The restaurant and lounge were not open due to COVID but we are definitely going to come back for the full experience. We stayed in the Manhattan King and the view is worth every single penny. '}

# %%
res5 = search_engine.get('HOTELS', 'FINDHOTEL', {'name' : 'Gusti Homestay'})
# Out:
# Hotels search engine in use!

# %%
res5
# Out:
# {'HOTEL_FEATURE': ['4 guestrooms',
#   'Breakfast available',
#   'Room service',
#   '24-hour front desk',
#   'Air conditioning',
#   'Garden',
#   'Self-serve laundry',
#   'Barbecue grills',
#   'Free WiFi and free parking '],
#  'LOCATION_SECTION': ['Majlis Daerah Kota Belud - 3.8 mi / 6.2 km',
#   'Tamu Kota Belud - 4 mi / 6.4 km',
#   'Mount Kinabalu National Park - 12.5 mi / 20.1 km',
#   'Pandan Pandan Island - 15.2 mi / 24.5 km',
#   'Upside Down House - 27.7 mi / 44.6 km',
#   'Tuaran Crocodile Farm - 28.6 mi / 46 km',
#   'Dalit Beach - 30.3 mi / 48.8 km',
#   'Tamparuli Suspension Bridge - 30.3 mi / 48.8 km',
#   'Karambunai Peninsula - 31.5 mi / 50.7 km'],
#  'TAGLINE': ['<b>No-frills hotel in Kota Belud </b>'],
#  'HOTEL_FREEBIES': ['Free WiFi and free parking'],
#  'NAME': 'Taun Gusi Village Homestay',
#  'STAR_RATE': 2.5,
#  'PRICE': 14.0,
#  'longitude': 116.436452,
#  'latitude': 6.381239,
#  'ROOMS': [' Budget Twin Share Room'],
#  'ROOM_FEATURES': ['Air conditioning',
#   'Coffee/tea maker',
#   'Slippers',
#   'Iron/ironing board (on request)',
#   'Shared bathroom',
#   'Shower only',
#   'Desk',
#   'Free WiFi',
#   'Free bottled water'],
#  'HOTEL_FEATURES': [{'heading': 'Food and drink',
#    'listItems': ['Local cuisine breakfast (surcharge)',
#     'Room service',
#     'Barbecue grills']},
#   {'heading': 'Services',
#    'listItems': ['24-hour front desk', 'Laundry facilities']},
#   {'heading': 'Facilities', 'listItems': ['Garden']},
#   {'heading': 'Languages Spoken', 'listItems': ['English']}],
#  'POLICIES': '<p>Some facilities may have restricted access. Guests can contact the property for details using the contact information on the booking confirmation. </p>',
#  'PETS': ['Pets not allowed'],
#  'INTERNET': ['Free WiFi in public areas', 'Free WiFi in rooms'],
#  'MAP_URL': 'https://maps-api-ssl.google.com/maps/api/staticmap?center=6.381239,116.436452&format=jpg&sensor=false&key=AIzaSyDaDqDNrxWrxcURixO2l6TbtV68X0Klf4U&zoom=16&size=834x443&scale&signature&signature=iALmgOdbrapsVIbRKhifflNe4DQ=',
#  'CHECKIN_REQUIRED': ['Credit card, debit card, or cash deposit required for incidental charges',
#   'Government-issued photo ID may be required',
#   'Minimum check-in age is 18']}

# %%
features = list_to_str(res5['HOTEL_FEATURE']) + list_to_str(res5['HOTEL_FREEBIES']) + list_to_str(res5['ROOMS']) +  list_to_str(res5['ROOM_FEATURES'])

# %%
features
# Out:
# "172 smoke-free guestrooms,Daily housekeeping,Restaurant and 2 bars/lounges,Breakfast available,24-hour health club,Self parking,Train station pick-up service,24-hour front desk,Air conditioning,Front desk safe,ATM/banking services,Laundry service,Free WiFi ,Free WiFi,Design Room, 1 King Bed, Accessible (Journeyman),Design Room, 2 Queen Beds, Accessible (Journeyman),Suite (Diamond),Room, 2 Queen Beds (Craftsman),Room, Multiple Beds (Journeyman Bunk Bed),Room, 1 King Bed (Journeyman),Room, 2 Queen Beds (Journeyman),Room, 1 King Bed (Master),Loft (Maven's),Room, 2 Queen Beds (Master),Suite (Maker's),Suite, 1 King Bed (Innovator),Suite, 2 Queen Beds (Innovator),Room, 1 King Bed (Apprentice),Room, 1 King Bed (Craftsman),Room, Multiple Beds (Craftsman Bunk Bed),Air conditioning,Coffee/tea maker,Bathrobes,Iron/ironing board,Hypo-allergenic bedding available,Blackout drapes/curtains,Soundproofed rooms,Turndown service,Premium bedding,Private bathroom,Shower/tub combination,Designer toiletries,42-inch flat-screen TV,Pay movies,Premium TV channels,Desk,Free WiFi,Phone,Free bottled water,Daily housekeeping,In-room safe,Connecting/adjoining rooms available,"

# %%
res5
# Out:
# {'HOTEL_FEATURE': ['172 smoke-free guestrooms',
#   'Daily housekeeping',
#   'Restaurant and 2 bars/lounges',
#   'Breakfast available',
#   '24-hour health club',
#   'Self parking',
#   'Train station pick-up service',
#   '24-hour front desk',
#   'Air conditioning',
#   'Front desk safe',
#   'ATM/banking services',
#   'Laundry service',
#   'Free WiFi '],
#  'LOCATION_SECTION': ['In LoDo',
#   'Coors Field - 3 min walk',
#   'Union Station - 5 min walk',
#   '16th Street Mall - 10 min walk',
#   'Ball Arena - 16 min walk',
#   'Empower Field at Mile High - 35 min walk',
#   'Larimer Square - 9 min walk',
#   'Elitch Gardens Theme Park - 19 min walk',
#   "Denver's Downtown Aquarium - 26 min walk",
#   "Children's Museum of Denver - 30 min walk"],
#  'TAGLINE': ['<b>4-star hotel with 2 bars/lounges, near Coors Field </b>'],
#  'HOTEL_FREEBIES': ['Free WiFi'],
#  'NAME': 'The Maven at Dairy Block',
#  'STAR_RATE': 4.0,
#  'PRICE': 199.0,
#  'longitude': -104.99656,
#  'latitude': 39.75348,
#  'ROOMS': ['Design Room, 1 King Bed, Accessible (Journeyman)',
#   'Design Room, 2 Queen Beds, Accessible (Journeyman)',
#   'Suite (Diamond)',
#   'Room, 2 Queen Beds (Craftsman)',
#   'Room, Multiple Beds (Journeyman Bunk Bed)',
#   'Room, 1 King Bed (Journeyman)',
#   'Room, 2 Queen Beds (Journeyman)',
#   'Room, 1 King Bed (Master)',
#   "Loft (Maven's)",
#   'Room, 2 Queen Beds (Master)',
#   "Suite (Maker's)",
#   'Suite, 1 King Bed (Innovator)',
#   'Suite, 2 Queen Beds (Innovator)',
#   'Room, 1 King Bed (Apprentice)',
#   'Room, 1 King Bed (Craftsman)',
#   'Room, Multiple Beds (Craftsman Bunk Bed)'],
#  'ROOM_FEATURES': ['Air conditioning',
#   'Coffee/tea maker',
#   'Bathrobes',
#   'Iron/ironing board',
#   'Hypo-allergenic bedding available',
#   'Blackout drapes/curtains',
#   'Soundproofed rooms',
#   'Turndown service',
#   'Premium bedding',
#   'Private bathroom',
#   'Shower/tub combination',
#   'Designer toiletries',
#   '42-inch flat-screen TV',
#   'Pay movies',
#   'Premium TV channels',
#   'Desk',
#   'Free WiFi',
#   'Phone',
#   'Free bottled water',
#   'Daily housekeeping',
#   'In-room safe',
#   'Connecting/adjoining rooms available'],
#  'HOTEL_FEATURES': [{'heading': 'Food and drink',
#    'listItems': ['Full breakfast daily (surcharge)',
#     '2 bars/lounges',
#     'Restaurant',
#     'Coffee shop/café',
#     'Room service (during limited hours)']},
#   {'heading': 'Things to do', 'listItems': ['24-hour fitness facilities']},
#   {'heading': 'Working away', 'listItems': ['One meeting room']},
#   {'heading': 'Services',
#    'listItems': ['24-hour front desk',
#     'Concierge services',
#     'Tours/ticket assistance',
#     'Dry cleaning/laundry service',
#     'Luggage storage']},
#   {'heading': 'Facilities',
#    'listItems': ['Number of buildings/towers -  1',
#     'Year Built -  2017',
#     'Elevator',
#     'ATM/banking',
#     'Safe-deposit box at front desk']},
#   {'heading': 'Accessibility',
#    'listItems': ['Braille or raised signage',
#     'Accessible bathroom',
#     'Roll-in shower',
#     'Wheelchair-accessible path of travel',
#     'Wheelchair-accessible parking',
#     'Assistive listening devices available',
#     'Wheelchair-accessible concierge desk',
#     'Wheelchair-accessible path to lift',
#     'Wheelchair-accessible registration desk',
#     'Wheelchair-accessible meeting spaces/business center',
#     'Wheelchair-accessible on-site restaurant',
#     'Wheelchair-accessible lounge']},
#   {'heading': 'Languages Spoken', 'listItems': ['English']}],
#  'HYGIENE': 'COVID-19: Hygiene and cleanliness',
#  'POLICIES': '<p>The property has connecting/adjoining rooms, which are subject to availability and can be requested by contacting the property using the number on the booking confirmation. </p><p>Noise-free guestrooms cannot be guaranteed. </p><p>This property advises that enhanced cleaning and guest safety measures are currently in place.</p><p>Disinfectant is used to clean the property.</p><p>Social distancing measures are in place; staff at the property wear personal protective equipment; a shield is in place between staff and guests in main contact areas; guests are provided with hand sanitizer.</p><p>Contactless check-out is available.</p><p>Each guestroom is kept vacant for a minimum of 48 hours between bookings.</p>',
#  'PETS': ['Pets allowed*', '2 per room'],
#  'INTERNET': ['Free WiFi in public areas', 'Free WiFi in rooms'],
#  'MAP_URL': 'https://maps-api-ssl.google.com/maps/api/staticmap?center=39.75348,-104.99656&format=jpg&sensor=false&key=AIzaSyDaDqDNrxWrxcURixO2l6TbtV68X0Klf4U&zoom=16&size=834x443&scale&signature&signature=FR9MLXb2VQaW6TazfOPjGaFkiAc=',
#  'CHECKIN_REQUIRED': ['Credit card, debit card, or cash deposit required for incidental charges',
#   'Government-issued photo ID may be required',
#   'Minimum check-in age is 21']}

# %% [markdown]
# ### Section two - Places search engine testing

# %%
res6 = search_engine.get('PLACES', 'LOCATION', {'name' : 'istanbul'})
# Out:
# Places search engine in use!

# %%
res6[0]
# Out:
# {'id': 'W331188177',
#  'name': 'Bıçakçı Alaaddin Cami',
#  'guestrating': 1,
#  'kinds': 'religion,other_temples,interesting_places',
#  'distance': 6.1449093,
#  'coordinate': {'lat': 41.013805, 'lon': 28.949715}}

# %%
res7 = search_engine.get('PLACES', 'DETAILS', {'id' : 'R1918'})
# Out:
# Places search engine in use!

# %%
res7
# Out:
# {'xid': 'R1918',
#  'name': 'Sforza Castle',
#  'address': {'city': 'Milano',
#   'state': 'LOM',
#   'county': 'MI',
#   'suburb': 'Municipio 1',
#   'country': 'Italia',
#   'footway': 'Cortile della Rocchetta',
#   'country_code': 'it',
#   'neighbourhood': 'Castello'},
#  'rate': '3h',
#  'osm': 'relation/1918',
#  'bbox': {'lon_min': 9.177768,
#   'lon_max': 9.181365,
#   'lat_min': 45.469006,
#   'lat_max': 45.471544},
#  'wikidata': 'Q23354',
#  'kinds': 'fortifications,historic,monuments_and_memorials,interesting_places,castles,monuments',
#  'url': 'https://www.milanocastello.it/;http://www.milanocastello.it/',
#  'sources': {'geometry': 'osm', 'attributes': ['osm', 'wikidata']},
#  'otm': 'https://opentripmap.com/en/card/R1918',
#  'wikipedia': 'https://en.wikipedia.org/wiki/Sforza%20Castle',
#  'image': 'https://commons.wikimedia.org/wiki/File:20110725_Castello_Sforzesco_Milan_5557.jpg',
#  'preview': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/20110725_Castello_Sforzesco_Milan_5557.jpg/266px-20110725_Castello_Sforzesco_Milan_5557.jpg',
#   'height': 400,
#   'width': 266},
#  'wikipedia_extracts': {'title': 'en:Sforza Castle',
#   'text': "Sforza Castle (Italian: Castello Sforzesco) is in Milan, northern Italy. It was built in the 15th century by Francesco Sforza, Duke of Milan, on the remnants of a 14th-century fortification. Later renovated and enlarged, in the 16th and 17th centuries it was one of the largest citadels in Europe. Extensively rebuilt by Luca Beltrami in 1891–1905, it now houses several of the city's museums and art collections.",
#   'html': '<p><b>Sforza Castle</b> (Italian: <i lang="it">Castello Sforzesco</i>) is in Milan, northern Italy. It was built in the 15th century by Francesco Sforza, Duke of Milan, on the remnants of a 14th-century fortification. Later renovated and enlarged, in the 16th and 17th centuries it was one of the largest citadels in Europe. Extensively rebuilt by Luca Beltrami in 1891–1905, it now houses several of the city\'s museums and art collections.</p>'},
#  'point': {'lon': 9.178132, 'lat': 45.470272}}

# %%
res8 = search_engine.get('PLACES', 'LISTVIEW', {'name' : 'istanbul', 'filter' : 'interesting_places'})
# Out:
# Places search engine in use!

# %%
res8
# Out:
# [{'xid': 'W331188177', 'name': 'Bıçakçı Alaaddin Cami', 'rate': '1'},
#  {'xid': 'W523880524', 'name': 'Sofular Molla Hüsrev Camii', 'rate': '1'}]

# %%
res9 = search_engine.get('PLACES', 'COORDINATES', {'lon' : '28.838911',
                                                   'lat' : '40.958549',
                                                   'filter' : 'restaurants'})
# Out:
# Places search engine in use!

# %%
res9['features'][0]
# Out:
# {'type': 'Feature',
#  'id': '9481637',
#  'geometry': {'type': 'Point', 'coordinates': [28.838911, 40.958549]},
#  'properties': {'xid': 'N1380962608',
#   'name': 'Old lighthouse Fener',
#   'dist': 0.15705226,
#   'rate': 3,
#   'osm': 'node/1380962608',
#   'wikidata': 'Q8053369',
#   'kinds': 'restaurants,foods,tourist_facilities'}}

# %% [markdown]
# ### Collecting Places Dataset
# **get_place_features from places.py** rreturns the following features for each place in a wanted location:
#  1.  `ID`
#  2.  `NAME`
#  3.  `RATE`
#  4.  `Kinds`
#
# a search query to find all places in **Istanbul** for example, the first result is:
# `{'id': 'W331188177',
#  'name': 'Bıçakçı Alaaddin Cami',
#  'rate': 1,
#  'kinds': 'religion,other_temples,interesting_places'}`

# %%
test = places.get_place_features('istanbul','religion')
df = pd.DataFrame(test)

# %%
df.to_csv('dataset/religion_dataset.csv',index = False)

# %%
df2 = pd.read_csv('dataset/final_places_dataset.csv')

# %%
cities_name = df2.city.unique()

# %%
for city in cities_name:
    test = places.get_place_features(city,'religion' )
    df_ = pd.DataFrame(test)
    df_.to_csv('dataset/religion_dataset.csv', mode='a', header=False, index = False)

# %%
df = pd.read_csv('dataset/religion_dataset.csv')

# %%
df = df.drop_duplicates(subset=['name'])

# %%
df = df.dropna(subset=['name'])

# %%
df.head()

# %%
len(df.index)

# %%
df.to_csv('dataset/religion_dataset.csv',index = False)

# %%
df1 = pd.read_csv('dataset/cultural_dataset.csv')
df2 = pd.read_csv('dataset/religion_dataset.csv')
df3 = pd.read_csv('dataset/historic_dataset.csv')
df4 = pd.read_csv('dataset/architecture_dataset.csv')
df5 = pd.read_csv('dataset/natural_dataset.csv')

# %%
df1 = df1.append(df2, ignore_index=True)
df1 = df1.append(df3, ignore_index=True)
df1 = df1.append(df4, ignore_index=True)
df1 = df1.append(df5, ignore_index=True)

# %%
df1 = df1.drop_duplicates(subset=['name'])
df1 = df1.drop_duplicates(subset=['id'])
df1 = df1.dropna(subset=['name'])

# %%
len(df1.index)

# %%
df1.to_csv('dataset/final_places_dataset2.csv',index = False)
